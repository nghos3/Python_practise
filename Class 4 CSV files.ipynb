# %%
import csv

with open('DATA/csv.csv') as csvfile:
     mpg = list(csv.DictReader(csvfile))
    
mpg
# Out:
# [OrderedDict([('Start Date ', '10/5/13'),
#               ('Start Time', '7:00 AM'),
#               ('End Date', '10/5/13'),
#               ('End Time', '7:30 AM'),
#               ('Event Title ', 'Parent Teacher Conference'),
#               ('Event Description',
#                'Register for a half hour parent teacher conference. '),
#               ('All Day Event', 'N'),
#               ('No End Time', 'N'),
#               ('Contact ', 'Chris Gallagher'),
#               ('Contact Email', 'cgallagher@schoolwires.com'),
#               ('Contact Phone', '814-555-5179'),
#               ('Location', 'Room 203'),
#               ('Category', '2'),
#               ('Registration', 'Y'),
#               ('Maximum Seats', '1'),
#               ('Last Date To Register', '10/4/13')]),
#  OrderedDict([('Start Date ', '10/5/13'),
#               ('Start Time', '7:30 AM'),
#               ('End Date', '10/5/13'),
#               ('End Time', '8:00 AM'),
# ...

# %%
len(mpg)
# Out:
# 24

# %%
mpg[0].keys()
# Out:
# odict_keys(['Start Date ', 'Start Time', 'End Date', 'End Time', 'Event Title ', 'Event Description', 'All Day Event', 'No End Time', 'Contact ', 'Contact Email', 'Contact Phone', 'Location', 'Category', 'Registration', 'Maximum Seats', 'Last Date To Register'])

# %%
#for mathematical operation numbers should be converted to float for operation 
#average catagory selected
sum(float(d['Category']) for d in mpg)/len(mpg)
# Out:
# 2.0
